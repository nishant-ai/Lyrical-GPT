# %%
import pandas as pd
from transformers import GPT2Tokenizer

# %%
# Load the GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token

# %%
# Maximum sequence length for GPT-2
max_length = 1024

# %%
# Read the combined CSV file
combined_file = 'combined_artists.csv'
df = pd.read_csv(combined_file)

# %%
# Create a new column with tokenized lyrics
def tokenize_lyrics(text):
    # Handle potential NaN values or non-string types
    if pd.isna(text) or not isinstance(text, str):
        return []
    
    # Tokenize the text and return the token IDs as a list
    tokens = tokenizer.encode(text)
    
    # Truncate tokens if they exceed the model's maximum length
    if len(tokens) > max_length:
        print(f"Truncating a lyric from {len(tokens)} tokens to {max_length}")
        tokens = tokens[:max_length]
    
    return tokens

# %%
# Apply the tokenization function to each lyric
print("Tokenizing lyrics... this may take a moment")
df['Tokenized_Lyrics'] = df['Lyric'].apply(tokenize_lyrics)
# Out:
# Tokenizing lyrics... this may take a moment
# Token indices sequence length is longer than the specified maximum sequence length for this model (1072 > 1024). Running this sequence through the model will result in indexing errors
# Truncating a lyric from 1072 tokens to 1024
# Truncating a lyric from 1075 tokens to 1024
# Truncating a lyric from 1215 tokens to 1024
# Truncating a lyric from 1222 tokens to 1024
# Truncating a lyric from 1408 tokens to 1024
# Truncating a lyric from 1192 tokens to 1024
# Truncating a lyric from 1077 tokens to 1024
# Truncating a lyric from 1036 tokens to 1024
# Truncating a lyric from 1075 tokens to 1024
# Truncating a lyric from 1083 tokens to 1024
# Truncating a lyric from 1080 tokens to 1024
# Truncating a lyric from 1055 tokens to 1024
# Truncating a lyric from 1215 tokens to 1024
# Truncating a lyric from 1143 tokens to 1024
# Truncating a lyric from 1050 tokens to 1024
# Truncating a lyric from 1036 tokens to 1024
# Truncating a lyric from 1177 tokens to 1024
# Truncating a lyric from 1280 tokens to 1024
# Truncating a lyric from 1118 tokens to 1024
# Truncating a lyric from 1351 tokens to 1024
# Truncating a lyric from 1043 tokens to 1024
# Truncating a lyric from 1679 tokens to 1024
# Truncating a lyric from 1189 tokens to 1024
# Truncating a lyric from 1151 tokens to 1024
# Truncating a lyric from 1066 tokens to 1024
# Truncating a lyric from 1077 tokens to 1024
# Truncating a lyric from 1061 tokens to 1024
# Truncating a lyric from 1200 tokens to 1024
# Truncating a lyric from 1187 tokens to 1024
# Truncating a lyric from 1177 tokens to 1024
# Truncating a lyric from 3283 tokens to 1024
# Truncating a lyric from 1755 tokens to 1024
# Truncating a lyric from 1342 tokens to 1024
# Truncating a lyric from 1083 tokens to 1024
# Truncating a lyric from 1987 tokens to 1024
# Truncating a lyric from 1729 tokens to 1024
# Truncating a lyric from 1194 tokens to 1024
# Truncating a lyric from 1031 tokens to 1024
# Truncating a lyric from 1512 tokens to 1024
# Truncating a lyric from 1892 tokens to 1024
# Truncating a lyric from 1374 tokens to 1024
# Truncating a lyric from 1073 tokens to 1024
# Truncating a lyric from 1771 tokens to 1024
# Truncating a lyric from 1838 tokens to 1024
# Truncating a lyric from 1782 tokens to 1024
# Truncating a lyric from 1467 tokens to 1024
# Truncating a lyric from 1677 tokens to 1024
# Truncating a lyric from 2175 tokens to 1024
# Truncating a lyric from 1522 tokens to 1024
# Truncating a lyric from 2152 tokens to 1024
# Truncating a lyric from 1384 tokens to 1024
# Truncating a lyric from 2618 tokens to 1024
# Truncating a lyric from 1475 tokens to 1024
# Truncating a lyric from 1777 tokens to 1024
# Truncating a lyric from 1210 tokens to 1024
# Truncating a lyric from 2281 tokens to 1024
# Truncating a lyric from 1760 tokens to 1024
# Truncating a lyric from 1143 tokens to 1024
# Truncating a lyric from 2384 tokens to 1024
# Truncating a lyric from 2333 tokens to 1024
# Truncating a lyric from 1706 tokens to 1024
# Truncating a lyric from 1415 tokens to 1024
# Truncating a lyric from 1502 tokens to 1024
# Truncating a lyric from 4589 tokens to 1024
# Truncating a lyric from 1193 tokens to 1024
# Truncating a lyric from 1712 tokens to 1024
# Truncating a lyric from 2312 tokens to 1024
# Truncating a lyric from 1139 tokens to 1024
# Truncating a lyric from 1331 tokens to 1024
# Truncating a lyric from 1207 tokens to 1024
# Truncating a lyric from 1329 tokens to 1024
# Truncating a lyric from 1942 tokens to 1024
# Truncating a lyric from 3208 tokens to 1024
# Truncating a lyric from 1505 tokens to 1024
# Truncating a lyric from 2371 tokens to 1024
# Truncating a lyric from 2005 tokens to 1024
# Truncating a lyric from 1053 tokens to 1024
# Truncating a lyric from 1625 tokens to 1024
# Truncating a lyric from 1768 tokens to 1024
# Truncating a lyric from 2002 tokens to 1024
# Truncating a lyric from 2288 tokens to 1024
# Truncating a lyric from 1076 tokens to 1024
# Truncating a lyric from 2565 tokens to 1024
# Truncating a lyric from 1322 tokens to 1024
# Truncating a lyric from 1353 tokens to 1024
# Truncating a lyric from 1481 tokens to 1024
# Truncating a lyric from 1720 tokens to 1024
# Truncating a lyric from 4715 tokens to 1024
# Truncating a lyric from 1160 tokens to 1024
# Truncating a lyric from 1671 tokens to 1024
# Truncating a lyric from 1953 tokens to 1024
# Truncating a lyric from 2045 tokens to 1024
# Truncating a lyric from 2877 tokens to 1024
# Truncating a lyric from 1716 tokens to 1024
# Truncating a lyric from 1533 tokens to 1024
# Truncating a lyric from 1438 tokens to 1024
# Truncating a lyric from 2340 tokens to 1024
# Truncating a lyric from 1642 tokens to 1024
# Truncating a lyric from 1431 tokens to 1024
# Truncating a lyric from 2322 tokens to 1024
# Truncating a lyric from 2289 tokens to 1024
# Truncating a lyric from 1228 tokens to 1024
# Truncating a lyric from 2158 tokens to 1024
# Truncating a lyric from 1209 tokens to 1024
# Truncating a lyric from 2680 tokens to 1024
# Truncating a lyric from 1108 tokens to 1024
# Truncating a lyric from 2307 tokens to 1024
# Truncating a lyric from 2283 tokens to 1024
# Truncating a lyric from 1924 tokens to 1024
# Truncating a lyric from 2066 tokens to 1024
# Truncating a lyric from 1458 tokens to 1024
# Truncating a lyric from 1822 tokens to 1024
# Truncating a lyric from 6390 tokens to 1024
# Truncating a lyric from 1504 tokens to 1024
# Truncating a lyric from 1295 tokens to 1024
# Truncating a lyric from 1406 tokens to 1024
# Truncating a lyric from 1125 tokens to 1024
# Truncating a lyric from 2099 tokens to 1024
# Truncating a lyric from 1296 tokens to 1024
# Truncating a lyric from 2092 tokens to 1024
# Truncating a lyric from 1549 tokens to 1024
# Truncating a lyric from 2154 tokens to 1024
# Truncating a lyric from 1564 tokens to 1024
# Truncating a lyric from 1879 tokens to 1024
# Truncating a lyric from 3316 tokens to 1024
# Truncating a lyric from 1166 tokens to 1024
# Truncating a lyric from 1388 tokens to 1024
# Truncating a lyric from 3913 tokens to 1024
# Truncating a lyric from 1318 tokens to 1024
# Truncating a lyric from 1033 tokens to 1024
# Truncating a lyric from 1196 tokens to 1024
# Truncating a lyric from 1370 tokens to 1024
# Truncating a lyric from 2230 tokens to 1024
# Truncating a lyric from 1249 tokens to 1024
# Truncating a lyric from 2166 tokens to 1024
# Truncating a lyric from 1817 tokens to 1024
# Truncating a lyric from 1833 tokens to 1024
# Truncating a lyric from 2460 tokens to 1024
# Truncating a lyric from 1542 tokens to 1024
# Truncating a lyric from 2341 tokens to 1024
# Truncating a lyric from 2486 tokens to 1024
# Truncating a lyric from 1259 tokens to 1024
# Truncating a lyric from 5510 tokens to 1024
# Truncating a lyric from 2027 tokens to 1024
# Truncating a lyric from 2724 tokens to 1024
# Truncating a lyric from 2418 tokens to 1024
# Truncating a lyric from 2305 tokens to 1024
# Truncating a lyric from 3933 tokens to 1024
# Truncating a lyric from 3920 tokens to 1024
# Truncating a lyric from 2274 tokens to 1024
# Truncating a lyric from 1883 tokens to 1024
# Truncating a lyric from 2863 tokens to 1024
# Truncating a lyric from 1347 tokens to 1024
# Truncating a lyric from 3786 tokens to 1024
# Truncating a lyric from 2179 tokens to 1024
# Truncating a lyric from 2239 tokens to 1024
# Truncating a lyric from 1611 tokens to 1024
# Truncating a lyric from 1370 tokens to 1024
# Truncating a lyric from 2538 tokens to 1024
# Truncating a lyric from 2727 tokens to 1024
# Truncating a lyric from 2729 tokens to 1024
# Truncating a lyric from 2316 tokens to 1024
# Truncating a lyric from 1079 tokens to 1024
# Truncating a lyric from 1346 tokens to 1024
# Truncating a lyric from 3206 tokens to 1024
# Truncating a lyric from 2365 tokens to 1024
# Truncating a lyric from 2139 tokens to 1024
# Truncating a lyric from 2901 tokens to 1024
# Truncating a lyric from 2765 tokens to 1024
# Truncating a lyric from 2318 tokens to 1024
# Truncating a lyric from 1292 tokens to 1024
# Truncating a lyric from 2394 tokens to 1024
# Truncating a lyric from 2456 tokens to 1024
# Truncating a lyric from 2020 tokens to 1024
# Truncating a lyric from 1403 tokens to 1024
# Truncating a lyric from 1432 tokens to 1024
# Truncating a lyric from 2635 tokens to 1024
# Truncating a lyric from 2893 tokens to 1024
# Truncating a lyric from 2489 tokens to 1024
# Truncating a lyric from 3878 tokens to 1024
# Truncating a lyric from 1844 tokens to 1024
# Truncating a lyric from 1666 tokens to 1024
# Truncating a lyric from 2425 tokens to 1024
# Truncating a lyric from 1866 tokens to 1024
# Truncating a lyric from 2079 tokens to 1024
# Truncating a lyric from 2577 tokens to 1024
# Truncating a lyric from 1851 tokens to 1024
# Truncating a lyric from 1366 tokens to 1024
# Truncating a lyric from 1962 tokens to 1024
# Truncating a lyric from 1964 tokens to 1024
# Truncating a lyric from 5111 tokens to 1024
# Truncating a lyric from 1752 tokens to 1024
# Truncating a lyric from 2793 tokens to 1024
# Truncating a lyric from 1912 tokens to 1024
# Truncating a lyric from 7789 tokens to 1024
# Truncating a lyric from 1406 tokens to 1024
# Truncating a lyric from 4421 tokens to 1024
# Truncating a lyric from 2347 tokens to 1024
# Truncating a lyric from 1256 tokens to 1024
# Truncating a lyric from 3065 tokens to 1024
# Truncating a lyric from 3477 tokens to 1024
# Truncating a lyric from 1313 tokens to 1024
# Truncating a lyric from 4025 tokens to 1024
# Truncating a lyric from 1819 tokens to 1024
# Truncating a lyric from 1442 tokens to 1024
# Truncating a lyric from 1732 tokens to 1024
# Truncating a lyric from 2387 tokens to 1024
# Truncating a lyric from 2307 tokens to 1024
# Truncating a lyric from 2473 tokens to 1024
# Truncating a lyric from 1438 tokens to 1024
# Truncating a lyric from 2039 tokens to 1024
# Truncating a lyric from 1532 tokens to 1024
# Truncating a lyric from 1566 tokens to 1024
# Truncating a lyric from 1076 tokens to 1024
# Truncating a lyric from 1437 tokens to 1024
# Truncating a lyric from 1446 tokens to 1024
# Truncating a lyric from 1325 tokens to 1024
# Truncating a lyric from 3145 tokens to 1024
# Truncating a lyric from 1080 tokens to 1024
# Truncating a lyric from 2632 tokens to 1024
# Truncating a lyric from 1242 tokens to 1024
# Truncating a lyric from 1737 tokens to 1024
# Truncating a lyric from 1153 tokens to 1024
# Truncating a lyric from 2401 tokens to 1024
# Truncating a lyric from 1322 tokens to 1024
# Truncating a lyric from 2031 tokens to 1024
# Truncating a lyric from 1205 tokens to 1024
# Truncating a lyric from 1298 tokens to 1024
# Truncating a lyric from 1053 tokens to 1024
# Truncating a lyric from 1272 tokens to 1024
# Truncating a lyric from 1154 tokens to 1024
# Truncating a lyric from 1338 tokens to 1024
# Truncating a lyric from 1349 tokens to 1024
# Truncating a lyric from 1112 tokens to 1024
# Truncating a lyric from 1135 tokens to 1024
# Truncating a lyric from 1898 tokens to 1024
# Truncating a lyric from 1251 tokens to 1024
# Truncating a lyric from 1212 tokens to 1024
# Truncating a lyric from 1449 tokens to 1024
# Truncating a lyric from 1747 tokens to 1024
# Truncating a lyric from 1115 tokens to 1024
# Truncating a lyric from 1569 tokens to 1024
# Truncating a lyric from 1495 tokens to 1024
# Truncating a lyric from 1203 tokens to 1024
# Truncating a lyric from 1221 tokens to 1024
# Truncating a lyric from 1133 tokens to 1024
# Truncating a lyric from 1698 tokens to 1024
# Truncating a lyric from 1079 tokens to 1024
# Truncating a lyric from 1043 tokens to 1024
# Truncating a lyric from 1071 tokens to 1024
# Truncating a lyric from 1171 tokens to 1024
# Truncating a lyric from 1127 tokens to 1024
# Truncating a lyric from 1158 tokens to 1024
# Truncating a lyric from 1129 tokens to 1024
# Truncating a lyric from 1604 tokens to 1024
# Truncating a lyric from 1411 tokens to 1024
# Truncating a lyric from 1049 tokens to 1024
# Truncating a lyric from 1176 tokens to 1024
# Truncating a lyric from 1080 tokens to 1024
# Truncating a lyric from 1321 tokens to 1024
# Truncating a lyric from 1346 tokens to 1024
# Truncating a lyric from 1098 tokens to 1024
# Truncating a lyric from 1502 tokens to 1024
# Truncating a lyric from 1270 tokens to 1024
# Truncating a lyric from 1768 tokens to 1024
# Truncating a lyric from 1415 tokens to 1024
# Truncating a lyric from 1288 tokens to 1024
# Truncating a lyric from 1468 tokens to 1024
# Truncating a lyric from 1142 tokens to 1024
# Truncating a lyric from 1092 tokens to 1024
# Truncating a lyric from 1138 tokens to 1024
# Truncating a lyric from 1848 tokens to 1024
# Truncating a lyric from 1564 tokens to 1024
# Truncating a lyric from 1117 tokens to 1024
# Truncating a lyric from 1124 tokens to 1024
# Truncating a lyric from 1098 tokens to 1024
# Truncating a lyric from 1252 tokens to 1024
# Truncating a lyric from 1311 tokens to 1024
# Truncating a lyric from 1472 tokens to 1024
# Truncating a lyric from 1387 tokens to 1024
# Truncating a lyric from 1717 tokens to 1024
# Truncating a lyric from 1250 tokens to 1024
# Truncating a lyric from 1156 tokens to 1024
# Truncating a lyric from 1113 tokens to 1024
# Truncating a lyric from 1148 tokens to 1024
# Truncating a lyric from 1513 tokens to 1024
# Truncating a lyric from 1124 tokens to 1024
# Truncating a lyric from 1494 tokens to 1024
# Truncating a lyric from 1294 tokens to 1024
# Truncating a lyric from 1217 tokens to 1024
# Truncating a lyric from 1238 tokens to 1024
# Truncating a lyric from 1069 tokens to 1024
# Truncating a lyric from 1093 tokens to 1024
# Truncating a lyric from 1405 tokens to 1024
# Truncating a lyric from 1450 tokens to 1024
# Truncating a lyric from 1072 tokens to 1024
# Truncating a lyric from 1049 tokens to 1024
# Truncating a lyric from 1245 tokens to 1024
# Truncating a lyric from 1078 tokens to 1024
# Truncating a lyric from 1078 tokens to 1024
# Truncating a lyric from 1123 tokens to 1024
# Truncating a lyric from 1122 tokens to 1024
# Truncating a lyric from 1258 tokens to 1024
# Truncating a lyric from 3134 tokens to 1024
# Truncating a lyric from 1691 tokens to 1024
# Truncating a lyric from 1270 tokens to 1024
# Truncating a lyric from 1040 tokens to 1024
# Truncating a lyric from 1265 tokens to 1024
# Truncating a lyric from 1318 tokens to 1024
# Truncating a lyric from 1075 tokens to 1024
# Truncating a lyric from 1054 tokens to 1024
# Truncating a lyric from 1167 tokens to 1024
# Truncating a lyric from 1146 tokens to 1024
# Truncating a lyric from 1100 tokens to 1024
# Truncating a lyric from 1026 tokens to 1024
# Truncating a lyric from 1077 tokens to 1024
# Truncating a lyric from 1293 tokens to 1024
# Truncating a lyric from 1026 tokens to 1024
# Truncating a lyric from 1306 tokens to 1024
# Truncating a lyric from 1159 tokens to 1024
# Truncating a lyric from 1205 tokens to 1024
# Truncating a lyric from 1449 tokens to 1024
# Truncating a lyric from 1340 tokens to 1024
# Truncating a lyric from 1153 tokens to 1024
# Truncating a lyric from 1260 tokens to 1024
# Truncating a lyric from 1070 tokens to 1024
# Truncating a lyric from 1115 tokens to 1024
# Truncating a lyric from 1118 tokens to 1024
# Truncating a lyric from 1127 tokens to 1024
# Truncating a lyric from 1063 tokens to 1024
# Truncating a lyric from 1055 tokens to 1024
# Truncating a lyric from 1291 tokens to 1024
# Truncating a lyric from 1244 tokens to 1024
# Truncating a lyric from 1081 tokens to 1024
# Truncating a lyric from 1288 tokens to 1024
# Truncating a lyric from 1569 tokens to 1024
# Truncating a lyric from 1244 tokens to 1024
# Truncating a lyric from 1239 tokens to 1024
# Truncating a lyric from 1080 tokens to 1024
# Truncating a lyric from 1081 tokens to 1024
# Truncating a lyric from 2169 tokens to 1024
# Truncating a lyric from 1116 tokens to 1024
# Truncating a lyric from 1042 tokens to 1024
# Truncating a lyric from 1185 tokens to 1024
# Truncating a lyric from 1127 tokens to 1024
# Truncating a lyric from 1223 tokens to 1024
# Truncating a lyric from 1904 tokens to 1024
# Truncating a lyric from 1068 tokens to 1024
# Truncating a lyric from 1206 tokens to 1024
# Truncating a lyric from 1811 tokens to 1024
# Truncating a lyric from 1074 tokens to 1024
# Truncating a lyric from 1078 tokens to 1024
# Truncating a lyric from 1145 tokens to 1024
# Truncating a lyric from 1034 tokens to 1024
# Truncating a lyric from 1209 tokens to 1024
# Truncating a lyric from 1102 tokens to 1024
# Truncating a lyric from 1503 tokens to 1024
# Truncating a lyric from 1238 tokens to 1024
# Truncating a lyric from 1104 tokens to 1024
# Truncating a lyric from 1122 tokens to 1024
# Truncating a lyric from 1089 tokens to 1024
# Truncating a lyric from 1056 tokens to 1024
# Truncating a lyric from 1049 tokens to 1024
# Truncating a lyric from 1039 tokens to 1024
# Truncating a lyric from 1108 tokens to 1024
# Truncating a lyric from 1068 tokens to 1024
# Truncating a lyric from 1178 tokens to 1024
# Truncating a lyric from 1220 tokens to 1024
# Truncating a lyric from 1211 tokens to 1024
# Truncating a lyric from 1207 tokens to 1024
# Truncating a lyric from 2031 tokens to 1024
# Truncating a lyric from 1122 tokens to 1024
# Truncating a lyric from 1070 tokens to 1024
# Truncating a lyric from 1860 tokens to 1024
# Truncating a lyric from 1076 tokens to 1024
# Truncating a lyric from 1125 tokens to 1024
# Truncating a lyric from 1070 tokens to 1024
# Truncating a lyric from 1436 tokens to 1024
# Truncating a lyric from 1185 tokens to 1024
# Truncating a lyric from 1695 tokens to 1024
# Truncating a lyric from 1929 tokens to 1024
# Truncating a lyric from 4872 tokens to 1024
# Truncating a lyric from 1055 tokens to 1024
# Truncating a lyric from 1063 tokens to 1024
# Truncating a lyric from 1080 tokens to 1024
# Truncating a lyric from 1199 tokens to 1024
# Truncating a lyric from 1572 tokens to 1024
# Truncating a lyric from 2030 tokens to 1024
# Truncating a lyric from 1670 tokens to 1024
# Truncating a lyric from 1045 tokens to 1024
# Truncating a lyric from 1313 tokens to 1024
# Truncating a lyric from 1686 tokens to 1024
# Truncating a lyric from 1127 tokens to 1024
# Truncating a lyric from 1267 tokens to 1024
# Truncating a lyric from 2168 tokens to 1024
# Truncating a lyric from 1303 tokens to 1024
# Truncating a lyric from 1225 tokens to 1024
# Truncating a lyric from 3537 tokens to 1024
# Truncating a lyric from 1107 tokens to 1024
# Truncating a lyric from 1234 tokens to 1024
# Truncating a lyric from 3350 tokens to 1024
# Truncating a lyric from 2099 tokens to 1024
# Truncating a lyric from 1898 tokens to 1024
# Truncating a lyric from 8504 tokens to 1024
# Truncating a lyric from 1536 tokens to 1024
# Truncating a lyric from 2692 tokens to 1024
# Truncating a lyric from 1460 tokens to 1024
# Truncating a lyric from 2529 tokens to 1024
# Truncating a lyric from 1619 tokens to 1024
# Truncating a lyric from 1757 tokens to 1024
# Truncating a lyric from 3523 tokens to 1024
# Truncating a lyric from 1762 tokens to 1024
# Truncating a lyric from 3341 tokens to 1024
# Truncating a lyric from 1748 tokens to 1024
# Truncating a lyric from 1282 tokens to 1024
# Truncating a lyric from 1144 tokens to 1024
# Truncating a lyric from 1256 tokens to 1024
# Truncating a lyric from 1862 tokens to 1024
# Truncating a lyric from 1220 tokens to 1024
# Truncating a lyric from 2456 tokens to 1024
# Truncating a lyric from 1462 tokens to 1024
# Truncating a lyric from 2835 tokens to 1024
# Truncating a lyric from 2555 tokens to 1024
# Truncating a lyric from 1332 tokens to 1024
# Truncating a lyric from 1923 tokens to 1024
# Truncating a lyric from 1374 tokens to 1024
# Truncating a lyric from 1146 tokens to 1024
# Truncating a lyric from 1372 tokens to 1024
# Truncating a lyric from 1569 tokens to 1024
# Truncating a lyric from 1098 tokens to 1024
# Truncating a lyric from 1277 tokens to 1024
# Truncating a lyric from 1121 tokens to 1024
# Truncating a lyric from 1203 tokens to 1024
# Truncating a lyric from 1108 tokens to 1024
# Truncating a lyric from 1088 tokens to 1024
# Truncating a lyric from 1045 tokens to 1024
# Truncating a lyric from 1066 tokens to 1024
# Truncating a lyric from 1109 tokens to 1024
# Truncating a lyric from 1185 tokens to 1024
# Truncating a lyric from 1247 tokens to 1024
# Truncating a lyric from 3842 tokens to 1024
# Truncating a lyric from 1072 tokens to 1024
# Truncating a lyric from 1141 tokens to 1024
# Truncating a lyric from 2268 tokens to 1024
# Truncating a lyric from 1197 tokens to 1024
# Truncating a lyric from 1131 tokens to 1024
# Truncating a lyric from 1123 tokens to 1024
# Truncating a lyric from 6564 tokens to 1024
# Truncating a lyric from 1055 tokens to 1024
# Truncating a lyric from 1028 tokens to 1024
# Truncating a lyric from 1225 tokens to 1024
# Truncating a lyric from 1963 tokens to 1024
# Truncating a lyric from 1347 tokens to 1024
# Truncating a lyric from 1152 tokens to 1024
# Truncating a lyric from 1225 tokens to 1024
# Truncating a lyric from 1031 tokens to 1024
# Truncating a lyric from 1246 tokens to 1024
# Truncating a lyric from 1037 tokens to 1024
# Truncating a lyric from 1927 tokens to 1024
# Truncating a lyric from 1110 tokens to 1024
# Truncating a lyric from 1041 tokens to 1024
# Truncating a lyric from 1392 tokens to 1024
# Truncating a lyric from 1517 tokens to 1024
# Truncating a lyric from 1050 tokens to 1024
# Truncating a lyric from 2225 tokens to 1024
# Truncating a lyric from 1030 tokens to 1024
# Truncating a lyric from 1784 tokens to 1024
# Truncating a lyric from 1089 tokens to 1024
# Truncating a lyric from 1800 tokens to 1024
# Truncating a lyric from 1101 tokens to 1024
# Truncating a lyric from 1439 tokens to 1024
# Truncating a lyric from 2586 tokens to 1024
# Truncating a lyric from 1534 tokens to 1024
# Truncating a lyric from 1283 tokens to 1024
# Truncating a lyric from 3012 tokens to 1024
# Truncating a lyric from 1246 tokens to 1024
# Truncating a lyric from 1422 tokens to 1024
# Truncating a lyric from 2398 tokens to 1024
# Truncating a lyric from 1293 tokens to 1024
# Truncating a lyric from 2474 tokens to 1024
# Truncating a lyric from 1206 tokens to 1024
# Truncating a lyric from 1224 tokens to 1024
# Truncating a lyric from 1100 tokens to 1024
# Truncating a lyric from 1050 tokens to 1024
# Truncating a lyric from 1141 tokens to 1024
# Truncating a lyric from 1101 tokens to 1024
# Truncating a lyric from 1034 tokens to 1024

# %%
# Save the updated DataFrame to a new CSV
output_file = 'combined_artists_tokenized.csv'
df.to_csv(output_file, index=False)

print(f"Tokenized data saved to: {output_file}")
# Out:
# Tokenized data saved to: combined_artists_tokenized.csv

# %%
df.head()
# Out:
#      Artist                  Title             Album    Year        Date  \
# 0  Dua Lipa              New Rules          Dua Lipa  2017.0  2017-06-02
# 1  Dua Lipa        Don’t Start Now  Future Nostalgia  2019.0  2019-11-01
# 2  Dua Lipa                  IDGAF          Dua Lipa  2017.0  2017-06-02
# 3  Dua Lipa  Blow Your Mind (Mwah)          Dua Lipa  2016.0  2016-08-26
# 4  Dua Lipa             Be the One          Dua Lipa  2015.0  2015-10-30
#
#                                                Lyric  \
# 0  one one one one one   talkin' in my sleep at n...
# 1  if you don't wanna see me   did a full 80 craz...
# 2  you call me all friendly tellin' me how much y...
# 3  i know it's hot i know we've got something tha...
# 4  i see the moon i see the moon i see the moon o...
#
#                                     Tokenized_Lyrics
# 0  [505, 530, 530, 530, 530, 220, 220, 1561, 259,...
# 1  [361, 345, 836, 470, 18869, 766, 502, 220, 220...
# 2  [5832, 869, 502, 477, 8030, 1560, 259, 6, 502,...
# 3  [72, 760, 340, 338, 3024, 1312, 760, 356, 1053...
# 4  [72, 766, 262, 8824, 1312, 766, 262, 8824, 131...

# %%
# Count how many lyrics needed truncation
original_lengths = df['Lyric'].apply(lambda x: len(tokenizer.encode(x)) if isinstance(x, str) else 0)
truncated_count = sum(original_lengths > max_length)
print(f"\nNumber of lyrics that required truncation: {truncated_count}")
# Out:
# Number of lyrics that required truncation: 487

# %%
# Display a sample to verify tokenization
print("\nSample of tokenized data:")
sample_df = df[['Lyric', 'Tokenized_Lyrics']].head(3)
for index, row in sample_df.iterrows():
# "in the beginning god created heaven and earth for what it's worth i think that he might've created you first just my opinion your body is the one paradise that i wanna fly to every day and every night  pre i've been sick and tired of running chasing all of the flashing lights these late nights don't mean nothing so i just wanna apologize i'm sorry so sorry i'm sorry yeah   i need your love and i'm dying for the rush 'cause my heart ain't got enough i need your touch this is getting serious tell me that it's not the end of us how can we go back to the beginning how can we go back to the beginning without you i've got no air to breathe in how can we go back to the beginning   don't matter what's written we can start all over again all over again oh how can i get you all over my skin my deep intuition tells me that i'm doing you wrong if i don't come home just say you forgive me and don't let me go  pre i've been sick and tired of running chasing all of the flashing lights these late nights don't mean nothing so i just wanna apologize i'm sorry so sorry i'm sorry yeah   i need your love and i'm dying for the rush 'cause my heart ain't got enough i need your touch this is getting serious tell me that it's not the end of us how can we go back to the beginning how can we go back to the beginning without you i've got no air to breathe in how can we go back to the beginning   you know i'll roar like a lion for you you know i'll keep trying 'til the sun starts rising   i need your love and i'm dying for the rush 'cause my heart ain't got enough i need your touch this is getting serious tell me that it's not the end of us how can we go back to the beginning how can we go back to the beginning without you i've got no air to breathe in how can we go back to the beginning"

# %%
df["Tokenized_Lyrics"].iloc[12]
# Out:
# [259,
#  262,
#  3726,
#  5770,
#  2727,
#  9538,
#  290,
#  4534,
#  329,
#  644,
#  340,
#  338,
#  2861,
#  1312,
#  892,
#  326,
#  339,
#  1244,
#  1053,
#  2727,
#  345,
#  717,
#  655,
#  616,
#  4459,
#  534,
#  1767,
#  318,
#  262,
#  530,
#  31354,
#  326,
#  1312,
#  18869,
#  6129,
#  284,
#  790,
#  1110,
#  290,
#  790,
#  1755,
#  220,
#  662,
#  1312,
#  1053,
#  587,
#  6639,
#  290,
#  10032,
#  286,
#  2491,
#  20023,
#  477,
#  286,
#  262,
#  25293,
#  7588,
#  777,
#  2739,
#  12513,
#  836,
#  470,
#  1612,
#  2147,
#  523,
#  1312,
#  655,
#  18869,
#  16521,
#  1312,
#  1101,
#  7926,
#  523,
#  7926,
#  1312,
#  1101,
#  7926,
#  10194,
#  220,
#  220,
#  1312,
#  761,
#  534,
#  1842,
#  290,
#  1312,
#  1101,
#  9950,
#  329,
#  262,
#  10484,
#  705,
#  25587,
#  616,
#  2612,
#  18959,
#  470,
#  1392,
#  1576,
#  1312,
#  761,
#  534,
#  3638,
#  428,
#  318,
#  1972,
#  2726,
#  1560,
#  502,
#  326,
#  340,
#  338,
#  407,
#  262,
#  886,
#  286,
#  514,
#  703,
#  460,
#  356,
#  467,
#  736,
#  284,
#  262,
#  3726,
#  703,
#  460,
#  356,
#  467,
#  736,
#  284,
#  262,
#  3726,
#  1231,
#  345,
#  1312,
#  1053,
#  1392,
#  645,
#  1633,
#  284,
#  18044,
#  287,
#  703,
#  460,
#  356,
#  467,
#  736,
#  284,
#  262,
#  3726,
#  220,
#  220,
#  836,
#  470,
#  2300,
#  644,
#  338,
#  3194,
#  356,
#  460,
#  923,
#  477,
#  625,
#  757,
#  477,
#  625,
#  757,
#  11752,
#  703,
#  460,
#  1312,
#  651,
#  345,
#  477,
#  625,
#  616,
#  4168,
#  616,
#  2769,
#  31563,
#  4952,
#  502,
#  326,
#  1312,
#  1101,
#  1804,
#  345,
#  2642,
#  611,
#  1312,
#  836,
#  470,
#  1282,
#  1363,
#  655,
#  910,
#  345,
#  20927,
#  502,
#  290,
#  836,
#  470,
#  1309,
#  502,
#  467,
#  220,
#  662,
#  1312,
#  1053,
#  587,
#  6639,
#  290,
#  10032,
#  286,
#  2491,
#  20023,
#  477,
#  286,
#  262,
#  25293,
#  7588,
#  777,
#  2739,
#  12513,
#  836,
#  470,
#  1612,
#  2147,
#  523,
#  1312,
#  655,
#  18869,
#  16521,
#  1312,
#  1101,
#  7926,
#  523,
#  7926,
#  1312,
#  1101,
#  7926,
#  10194,
#  220,
#  220,
#  1312,
#  761,
#  534,
#  1842,
#  290,
#  1312,
#  1101,
#  9950,
#  329,
#  262,
#  10484,
#  705,
#  25587,
#  616,
#  2612,
#  18959,
#  470,
#  1392,
#  1576,
#  1312,
#  761,
#  534,
#  3638,
#  428,
#  318,
#  1972,
#  2726,
#  1560,
#  502,
#  326,
#  340,
#  338,
#  407,
#  262,
#  886,
#  286,
#  514,
#  703,
#  460,
#  356,
#  467,
#  736,
#  284,
#  262,
#  3726,
#  703,
#  460,
#  356,
#  467,
#  736,
#  284,
#  262,
#  3726,
#  1231,
#  345,
#  1312,
#  1053,
#  1392,
#  645,
#  1633,
#  284,
#  18044,
#  287,
#  703,
#  460,
#  356,
#  467,
#  736,
#  284,
#  262,
#  3726,
#  220,
#  220,
#  345,
#  760,
#  1312,
#  1183,
#  34532,
#  588,
#  257,
#  18744,
#  329,
#  345,
#  345,
#  760,
#  1312,
#  1183,
#  1394,
#  2111,
#  705,
#  47163,
#  262,
#  4252,
#  4940,
#  7396,
#  220,
#  220,
#  1312,
#  761,
#  534,
#  1842,
#  290,
#  1312,
#  1101,
#  9950,
#  329,
#  262,
#  10484,
#  705,
#  25587,
#  616,
#  2612,
#  18959,
#  470,
#  1392,
#  1576,
#  1312,
#  761,
#  534,
#  3638,
#  428,
#  318,
#  1972,
#  2726,
#  1560,
#  502,
#  326,
#  340,
#  338,
#  407,
#  262,
#  886,
#  286,
#  514,
#  703,
#  460,
#  356,
#  467,
#  736,
#  284,
#  262,
#  3726,
#  703,
#  460,
#  356,
#  467,
#  736,
#  284,
#  262,
#  3726,
#  1231,
#  345,
#  1312,
#  1053,
#  1392,
#  645,
#  1633,
#  284,
#  18044,
#  287,
#  703,
#  460,
#  356,
#  467,
#  736,
#  284,
#  262,
#  3726]

# %%
# Display a sample to verify tokenization
sample_df = df[['Lyric', 'Tokenized_Lyrics']].head(1)
for index, row in sample_df.iterrows():
    print(f"\nOriginal: {row['Lyric']}")
    print(f"Tokens: {row['Tokenized_Lyrics'][:10]}... (total: {len(row['Tokenized_Lyrics'])})")
    # Optionally decode a portion of the tokens back
    if row['Tokenized_Lyrics']:
        decoded = tokenizer.decode(row['Tokenized_Lyrics'])
        print(f"\nDecoded sample: {decoded}...")
# Out:
